# %%
# Imports 

import kagglehub
import numpy
import tarfile
from pathlib import Path
from urllib import request
import pandas as pd

# %%
df = kagglehub.dataset_download("fedesoriano/stroke-prediction-dataset")

# %%
# 1 - Carregamento e inspeção inicial

# %%
# 2 - Análise univariada

# %%
# 3 - Análise bivariada e multivariada

# Bivariada

# Multivariada

# %%
# Pré processamento
